# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
Input_Data_File = pd.read_csv("/content/gender_submission.csv")
Input_Test_File = pd.read_csv("/content/test.csv")
Input_Train_File =pd.read_csv("/content/train.csv")

# %%
print("Displaying the main file"+"\n")
Input_Data_File.head()
# Out:
# Displaying the main file
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
print("Displaying the Test file"+"\n")
Input_Test_File
# Out:
# Displaying the Test file
#      PassengerId  Pclass  ... Cabin Embarked
# 0            892       3  ...   NaN        Q
# 1            893       3  ...   NaN        S
# 2            894       2  ...   NaN        Q
# 3            895       3  ...   NaN        S
# 4            896       3  ...   NaN        S
# ..           ...     ...  ...   ...      ...
# 413         1305       3  ...   NaN        S
# 414         1306       1  ...  C105        C
# 415         1307       3  ...   NaN        S
# 416         1308       3  ...   NaN        S
# 417         1309       3  ...   NaN        C
#
# [418 rows x 11 columns]

# %%
print("Displaying the Train file"+"\n")
Input_Train_File
# Out:
# Displaying the Train file
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
X_label = Input_Data_File["Survived"]
Y_label = Input_Data_File["PassengerId"]

# %%
Alive = 0
Dead = 0
for index in X_label:
    if index == 0:
      Alive = Alive + 1
    else:
      Dead = Dead + 1

# %%
#print(Alive)
#print(Dead)
fig =plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(["Alive"], [Alive], color = ["red"] )
ax.bar(["Dead"], [Dead], color = ["yellow"])
plt.xlabel("Rate")
plt.ylabel("No.of Count")
plt.title("Death Analysis in Titanic Ship")
plt.show()

# %%
print("Welcome to the information section......!!!")
ID = input("Enter the passanger Id:"+" ")
for i in range (len(Input_Data_File["Survived"])):
   if float(ID) == float(Input_Data_File["PassengerId"][i]) : 
      
      if Input_Train_File["Survived"][i] == 0 :
        print("The passanger is Alive")
      else:
        print("Dead")
      print("Name of the passanger:"+" "+ Input_Train_File["Name"][i])
      print("Sex:"+" "+ Input_Train_File["Sex"][i])
      print("Age:"+" "+ str(Input_Train_File["Age"][i]))
      if str(Input_Train_File["Cabin"][i])  == "Nan" or str(Input_Train_File["Cabin"][i])  == "nan" :
        print("No Table Booked.........!!!")
      else:
        print("Table Name:"+" "+ str(Input_Train_File["Cabin"][i]))  
      print("Ticket number:"+" "+ Input_Train_File["Ticket"][i])  
   else:
        pass
# Out:
# Welcome to the information section......!!!
# Enter the passanger Id: 893
# Dead
# Name of the passanger: Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# Sex: female
# Age: 38.0
# Table Name: C85
# Ticket number: PC 17599
